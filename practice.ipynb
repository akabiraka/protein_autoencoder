# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from FastaDataset import FastaDataset

# %%
fd = FastaDataset("data/sample.fasta", encoding_mode='one_hot', pad_mode='end')
x = fd.__getitem__(0)
print(x.dtype)
# Out:
# torch.int64

# %%
x = torch.tensor([1, 2, 3], dtype=torch.float32)
y = torch.tensor([1, 3, 2], dtype=torch.float32)
z = F.sigmoid(x)
print(z)
F.binary_cross_entropy(x, y)
# Out:
# tensor([0.7311, 0.8808, 0.9526])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-369b1d693734> in <module>
#       3 z = F.sigmoid(x)
#       4 print(z)
# ----> 5 F.binary_cross_entropy(x, y)
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2075
#    2076     return torch._C._nn.binary_cross_entropy(
# -> 2077         input, target, weight, reduction_enum)
#    2078
#    2079
#
# RuntimeError: Assertion `x >= 0. && x <= 1.' failed. input value should be between 0~1, but got 2.000000 at /pytorch/aten/src/THNN/generic/BCECriterion.c:62

# %%
m = nn.Linear(20, 30)
input = torch.randn(128, 20)
output = m(input)
print(output.dtype)
# Out:
# torch.float32

# %%
import math
math.ceil(49255/50)
# Out:
# 986
